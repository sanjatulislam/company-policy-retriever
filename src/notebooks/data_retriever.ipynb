# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from scripts.retriever import retrieve_query
from scripts.engine import generate_final_response
# Out:
# simsimd not available — falling back to SciPy/NumPy implementation for vector math. To enable the accelerated path, install the optional dependency 'simsimd' (note: simsimd may require newer glibc on some systems).

# %%
query = "An employee loses a laptop containing RED-classified personal data while working remotely. What actions must be taken, who must be notified, and what policies govern the response?"

# %%
retriever_response = retrieve_query("An employee loses a laptop containing RED-classified personal data while working remotely. What actions must be taken, who must be notified, and what policies govern the response?")
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
for doc in retriever_response:
    print("="*40)
    print(f"{doc.metadata}\n")
    print(f"{doc.metadata.get("relevance_score")}\n")
    print(doc.page_content)
# Out:
# ...
# {'page_label': '12', 'source': 'acceptable-use-of-information-and-systems.pdf', 'chunk_id': 'acceptable-use-of-information-and-systems_41.pdf', 'relevance_score': 0.8259413}
#
# 0.8259413
#
# regular recycling paper bins for GREEN level (i.e. document does not
# contain personal or sensitive information).
#
# 7. Remote working within the UK
#
# a) Working on the move: it is permissible for staff to access and view SCC
# information in any format (paper or digital) while on the move providing
# that:
#
# i. No RED level information can be viewed by non-intended persons
# (e.g. adjacent seats on public transport, passers-by etc.).
#
# ii. The device, such as a laptop, must be shut-down and placed in a
# bag and safe-guarded when not in use, even for short period of
# time.
#
# iii. The loss of a device must be reported immediately as an
# Information Security Incident using the IT Self-service portal or
# contacting the IT Service Desk.
# ...

# %%
response = generate_final_response(query)
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
print(response)
# Out:
# Based on the provided documents, the following actions and policies apply:
#
# **Required Actions:**
# *   The loss of the device must be reported **immediately** as an Information Security Incident.
#
# **Notification Channels:**
# *   The incident must be reported using the **IT Self-service portal** or by contacting the **IT Service Desk**.
#
# **Governing Policies:**
# *   This requirement is governed by the policy for **Remote working within the UK**, specifically under the section for "Working on the move" (Section 7a).
# *   The policy explicitly states that if a device is lost while on the move, it must be reported immediately as an Information Security Incident.
