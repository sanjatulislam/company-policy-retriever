# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from scripts.query_decomposer import get_decomposed_queries
# Out:
# simsimd not available — falling back to SciPy/NumPy implementation for vector math. To enable the accelerated path, install the optional dependency 'simsimd' (note: simsimd may require newer glibc on some systems).

# %%
query = "How does SCC's Privacy by Design approach relate to its requirements for remote working with RED-level information?"

# %%
response = get_decomposed_queries(query)

print(response)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [
#   "What are the requirements for Privacy by Design in SCC's data protection policy?",
#   "What are the requirements for remote working with RED-level information in SCC's acceptable use policy?"
# ]
