# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from scripts.query_decomposer import get_decomposed_queries

# %%
query = "An employee loses a laptop containing RED-classified personal data while working remotely. What actions must be taken, who must be notified, and what policies govern the response?"

# %%
response = get_decomposed_queries(query)

print(response.content)
# Out:
# ["What actions must be taken when an employee loses a laptop containing RED-classified personal data?", "Who must be notified when a laptop containing RED-classified personal data is lost?", "What policies govern the response to the loss of a laptop containing RED-classified personal data?"]
